# %%
import csv

csv_file_path = 'food-truck-data.csv'

with open(csv_file_path, 'r') as file:
    csv_reader = csv.reader(file)

    header = next(csv_reader)
    
    trucks = []
    for row in csv_reader:
        data = dict(zip(header, row))
        trucks.append(data)
        print(data["Applicant"], data["Latitude"], data["Longitude"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /falcon/projects/interviews/4rakt/truck-finder/study/locator.ipynb Cell 1 line 5
#       <a href='vscode-notebook-cell:/falcon/projects/interviews/4rakt/truck-finder/study/locator.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import csv
#       <a href='vscode-notebook-cell:/falcon/projects/interviews/4rakt/truck-finder/study/locator.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> csv_file_path = 'food-truck-data.csv'
# ----> <a href='vscode-notebook-cell:/falcon/projects/interviews/4rakt/truck-finder/study/locator.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> with open(csv_file_path, 'r') as file:
#       <a href='vscode-notebook-cell:/falcon/projects/interviews/4rakt/truck-finder/study/locator.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a>     csv_reader = csv.reader(file)
#       <a href='vscode-notebook-cell:/falcon/projects/interviews/4rakt/truck-finder/study/locator.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a>     header = next(csv_reader)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'food-truck-data.csv'

# %%
! pip install pandas matplotlib
# Out:
# 26582.94s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/jack/.local/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: matplotlib in /home/jack/.local/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: haversine in /home/jack/.local/lib/python3.10/site-packages (2.8.0)
# Requirement already satisfied: numpy>=1.21.0 in /home/jack/.local/lib/python3.10/site-packages (from pandas) (1.23.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/jack/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jack/.local/lib/python3.10/site-packages (from matplotlib) (4.46.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jack/.local/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/jack/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /home/jack/.local/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jack/.local/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
#extract data from the csv file
food_trucks_df = pd.read_csv('../dataset/food-truck-data.csv')

# %%
food_trucks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   locationid                 481 non-null    int64
#  1   Applicant                  481 non-null    object
#  2   FacilityType               473 non-null    object
#  3   cnn                        481 non-null    int64
#  4   LocationDescription        463 non-null    object
#  5   Address                    481 non-null    object
#  6   blocklot                   471 non-null    object
#  7   block                      471 non-null    object
#  8   lot                        471 non-null    object
#  9   permit                     481 non-null    object
#  10  Status                     481 non-null    object
#  11  FoodItems                  475 non-null    object
#  12  X                          448 non-null    float64
#  13  Y                          448 non-null    float64
#  14  Latitude                   481 non-null    float64
#  15  Longitude                  481 non-null    float64
#  16  Schedule                   481 non-null    object
#  17  dayshours                  87 non-null     object
#  18  NOISent                    0 non-null      float64
#  19  Approved                   293 non-null    object
#  20  Received                   481 non-null    int64
#  21  PriorPermit                481 non-null    int64
#  22  ExpirationDate             458 non-null    object
#  23  Location                   481 non-null    object
#  24  Fire Prevention Districts  447 non-null    float64
#  25  Police Districts           447 non-null    float64
#  26  Supervisor Districts       447 non-null    float64
#  27  Zip Codes                  448 non-null    float64
#  28  Neighborhoods (old)        447 non-null    float64
# dtypes: float64(10), int64(4), object(15)
# memory usage: 109.1+ KB

# %%
food_trucks_df.head(10)
# Out:
#    locationid                                          Applicant FacilityType  \
# 0     1728067                                     Leo's Hot Dogs    Push Cart
# 1      735318                                   Ziaurehman Amini    Push Cart
# 2     1722089                                      Casita Vegana        Truck
# 3     1612654  Sunset Mercantile/Outer Sunset Farmers Market ...        Truck
# 4     1721249                     El Calamar Perubian Food Truck        Truck
# 5     1744305                                  BOWL'D ACAI, LLC.        Truck
# 6     1744303                                  BOWL'D ACAI, LLC.        Truck
# 7     1733728                                MOMO INNOVATION LLC        Truck
# 8     1733788                                MOMO INNOVATION LLC        Truck
# 9     1733610                                            Buenafe        Truck
#
#         cnn                                LocationDescription  \
# 0   9121000       MISSION ST: 19TH ST to 20TH ST (2300 - 2399)
# 1  30727000                   MARKET ST: DRUMM ST intersection
# 2   7553000  JOHN MUIR DR: LAKE MERCED BLVD to SKYLINE BLVD...
# 3   1835000   37TH AVE: QUINTARA ST to RIVERA ST (2100 - 2199)
# 4   9091000      MISSION ST: ANTHONY ST to 02ND ST (573 - 599)
# 5   9301000  MONTGOMERY ST: CALIFORNIA ST to SACRAMENTO ST ...
# 6   8122000  LARKIN ST: FULTON ST to MCALLISTER ST (200 - 299)
# 7   3527000  CALIFORNIA ST: BATTERY ST to SANSOME ST (300 -...
# 8   3525000    CALIFORNIA ST: DAVIS ST to FRONT ST (100 - 199)
# 9  10927000   RANKIN ST: DAVIDSON AVE to EVANS AVE (200 - 299)
#
#                        Address  blocklot block   lot       permit  ...  \
# 0              2301 MISSION ST   3595031  3595   031  23MFF-00008  ...
# 1            5 THE EMBARCADERO   0234017  0234   017   15MFF-0159  ...
# 2  Assessors Block 7283/Lot004   7283004  7283   004  23MFF-00005  ...
# 3                2155 37TH AVE   2094006  2094   006  22MFF-00031  ...
# 4                   85 02ND ST   3708019  3708   019  23MFF-00004  ...
# 5            451 MONTGOMERY ST   0240001  0240   001  23MFF-00049  ...
# 6                200 LARKIN ST   0353001  0353   001  23MFF-00048  ...
# 7            351 CALIFORNIA ST  0261010A  0261  010A  23MFF-00027  ...
# 8            101 CALIFORNIA ST   0263011  0263   011  23MFF-00029  ...
# 9                220 RANKIN ST   5228001  5228   001  23MFF-00025  ...
#
#                  Approved  Received  PriorPermit          ExpirationDate  \
# 0  09/20/2023 12:00:00 AM  20230920            1  11/15/2024 12:00:00 AM
# 1                     NaN  20151231            0  03/15/2016 12:00:00 AM
# 2  08/30/2023 12:00:00 AM  20230829            0  11/15/2024 12:00:00 AM
# 3                     NaN  20220421            0  11/15/2022 12:00:00 AM
# 4  08/31/2023 12:00:00 AM  20230825            0  11/15/2024 12:00:00 AM
# 5                     NaN  20231121            0  11/15/2024 12:00:00 AM
# 6                     NaN  20231121            0  11/15/2024 12:00:00 AM
# 7  10/18/2023 12:00:00 AM  20231016            0  11/15/2024 12:00:00 AM
# 8  10/18/2023 12:00:00 AM  20231017            0  11/15/2024 12:00:00 AM
# 9  10/18/2023 12:00:00 AM  20231013            0  11/15/2024 12:00:00 AM
#
#                                     Location  Fire Prevention Districts  \
# 0   (37.76008693198698, -122.41880648110114)                        2.0
# 1  (37.794331003246846, -122.39581105302317)                        4.0
# 2    (37.72188970870838, -122.4925212449949)                        1.0
# 3   (37.74732654654123, -122.49628067270531)                        1.0
# 4   (37.788457028828915, -122.3998841605663)                       12.0
# 5   (37.79357693326183, -122.40322987670133)                        4.0
# 6   (37.78021548028814, -122.41602577015111)                        7.0
# 7   (37.792870749741496, -122.4007474940767)                        4.0
# 8  (37.792948952834664, -122.39809861316652)                        4.0
# 9    (37.74574924062031, -122.3924814876784)                       10.0
#
#   Police Districts Supervisor Districts  Zip Codes Neighborhoods (old)
# 0              4.0                  7.0    28859.0                19.0
# 1              1.0                 10.0    28855.0                 6.0
# 2              8.0                  4.0       64.0                14.0
# 3              8.0                  3.0    29491.0                35.0
# 4              2.0                  9.0    28855.0                 6.0
# 5              1.0                 10.0    28854.0                 6.0
# 6             10.0                  9.0    28852.0                36.0
# 7              1.0                 10.0    28854.0                 6.0
# 8              1.0                 10.0    28860.0                 6.0
# 9              3.0                  8.0       58.0                 1.0
#
# [10 rows x 29 columns]

# %%
#Visualizing raw data, filtering the one outlier found in the csv file
Q1_lat = food_trucks_df['Latitude'].quantile(0.25)
Q3_lat = food_trucks_df['Latitude'].quantile(0.75)
IQR_lat = Q3_lat - Q1_lat

Q1_lon = food_trucks_df['Longitude'].quantile(0.25)
Q3_lon = food_trucks_df['Longitude'].quantile(0.75)
IQR_lon = Q3_lon - Q1_lon

threshold_lat = 1.5 * IQR_lat
threshold_lon = 1.5 * IQR_lon

filtered_data = food_trucks_df[
    (food_trucks_df['Latitude'] >= (Q1_lat - threshold_lat)) &
    (food_trucks_df['Latitude'] <= (Q3_lat + threshold_lat)) &
    (food_trucks_df['Longitude'] >= (Q1_lon - threshold_lon)) &
    (food_trucks_df['Longitude'] <= (Q3_lon + threshold_lon))
]

plt.figure(figsize=(10, 8))
plt.scatter(filtered_data['Longitude'], filtered_data['Latitude'], marker='o', color='blue')
plt.title('Filtered Food Truck Locations')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
coordinates = food_trucks_df[['Latitude', 'Longitude']]

# %%
scaler = StandardScaler()
coordinates_scaled = scaler.fit_transform(coordinates)

# %%
kmeans = KMeans(n_clusters=10)
food_trucks_df['cluster'] = kmeans.fit_predict(coordinates_scaled)

# %%
food_trucks_df.head(10)
# Out:
#    locationid                                          Applicant FacilityType  \
# 0     1728067                                     Leo's Hot Dogs    Push Cart
# 1      735318                                   Ziaurehman Amini    Push Cart
# 2     1722089                                      Casita Vegana        Truck
# 3     1612654  Sunset Mercantile/Outer Sunset Farmers Market ...        Truck
# 4     1721249                     El Calamar Perubian Food Truck        Truck
# 5     1744305                                  BOWL'D ACAI, LLC.        Truck
# 6     1744303                                  BOWL'D ACAI, LLC.        Truck
# 7     1733728                                MOMO INNOVATION LLC        Truck
# 8     1733788                                MOMO INNOVATION LLC        Truck
# 9     1733610                                            Buenafe        Truck
#
#         cnn                                LocationDescription  \
# 0   9121000       MISSION ST: 19TH ST to 20TH ST (2300 - 2399)
# 1  30727000                   MARKET ST: DRUMM ST intersection
# 2   7553000  JOHN MUIR DR: LAKE MERCED BLVD to SKYLINE BLVD...
# 3   1835000   37TH AVE: QUINTARA ST to RIVERA ST (2100 - 2199)
# 4   9091000      MISSION ST: ANTHONY ST to 02ND ST (573 - 599)
# 5   9301000  MONTGOMERY ST: CALIFORNIA ST to SACRAMENTO ST ...
# 6   8122000  LARKIN ST: FULTON ST to MCALLISTER ST (200 - 299)
# 7   3527000  CALIFORNIA ST: BATTERY ST to SANSOME ST (300 -...
# 8   3525000    CALIFORNIA ST: DAVIS ST to FRONT ST (100 - 199)
# 9  10927000   RANKIN ST: DAVIDSON AVE to EVANS AVE (200 - 299)
#
#                        Address  blocklot block   lot       permit  ...  \
# 0              2301 MISSION ST   3595031  3595   031  23MFF-00008  ...
# 1            5 THE EMBARCADERO   0234017  0234   017   15MFF-0159  ...
# 2  Assessors Block 7283/Lot004   7283004  7283   004  23MFF-00005  ...
# 3                2155 37TH AVE   2094006  2094   006  22MFF-00031  ...
# 4                   85 02ND ST   3708019  3708   019  23MFF-00004  ...
# 5            451 MONTGOMERY ST   0240001  0240   001  23MFF-00049  ...
# 6                200 LARKIN ST   0353001  0353   001  23MFF-00048  ...
# 7            351 CALIFORNIA ST  0261010A  0261  010A  23MFF-00027  ...
# 8            101 CALIFORNIA ST   0263011  0263   011  23MFF-00029  ...
# 9                220 RANKIN ST   5228001  5228   001  23MFF-00025  ...
#
#    Received PriorPermit          ExpirationDate  \
# 0  20230920           1  11/15/2024 12:00:00 AM
# 1  20151231           0  03/15/2016 12:00:00 AM
# 2  20230829           0  11/15/2024 12:00:00 AM
# 3  20220421           0  11/15/2022 12:00:00 AM
# 4  20230825           0  11/15/2024 12:00:00 AM
# 5  20231121           0  11/15/2024 12:00:00 AM
# 6  20231121           0  11/15/2024 12:00:00 AM
# 7  20231016           0  11/15/2024 12:00:00 AM
# 8  20231017           0  11/15/2024 12:00:00 AM
# 9  20231013           0  11/15/2024 12:00:00 AM
#
#                                     Location  Fire Prevention Districts  \
# 0   (37.76008693198698, -122.41880648110114)                        2.0
# 1  (37.794331003246846, -122.39581105302317)                        4.0
# 2    (37.72188970870838, -122.4925212449949)                        1.0
# 3   (37.74732654654123, -122.49628067270531)                        1.0
# 4   (37.788457028828915, -122.3998841605663)                       12.0
# 5   (37.79357693326183, -122.40322987670133)                        4.0
# 6   (37.78021548028814, -122.41602577015111)                        7.0
# 7   (37.792870749741496, -122.4007474940767)                        4.0
# 8  (37.792948952834664, -122.39809861316652)                        4.0
# 9    (37.74574924062031, -122.3924814876784)                       10.0
#
#    Police Districts Supervisor Districts Zip Codes  Neighborhoods (old)  \
# 0               4.0                  7.0   28859.0                 19.0
# 1               1.0                 10.0   28855.0                  6.0
# 2               8.0                  4.0      64.0                 14.0
# 3               8.0                  3.0   29491.0                 35.0
# 4               2.0                  9.0   28855.0                  6.0
# 5               1.0                 10.0   28854.0                  6.0
# 6              10.0                  9.0   28852.0                 36.0
# 7               1.0                 10.0   28854.0                  6.0
# 8               1.0                 10.0   28860.0                  6.0
# 9               3.0                  8.0      58.0                  1.0
#
#   cluster
# 0       4
# 1       6
# 2       7
# 3       9
# 4       6
# 5       6
# 6       5
# 7       6
# 8       6
# 9       8
#
# [10 rows x 30 columns]

# %%
Q1_lat = food_trucks_df['Latitude'].quantile(0.25)
Q3_lat = food_trucks_df['Latitude'].quantile(0.75)
IQR_lat = Q3_lat - Q1_lat

Q1_lon = food_trucks_df['Longitude'].quantile(0.25)
Q3_lon = food_trucks_df['Longitude'].quantile(0.75)
IQR_lon = Q3_lon - Q1_lon

# Define threshold for outliers
threshold_lat = 1.5 * IQR_lat
threshold_lon = 1.5 * IQR_lon

# Filter data outside the threshold
filtered_data = food_trucks_df[
    (food_trucks_df['Latitude'] >= (Q1_lat - threshold_lat)) &
    (food_trucks_df['Latitude'] <= (Q3_lat + threshold_lat)) &
    (food_trucks_df['Longitude'] >= (Q1_lon - threshold_lon)) &
    (food_trucks_df['Longitude'] <= (Q3_lon + threshold_lon))
]

# Plot the filtered cluster representation
plt.figure(figsize=(10, 8))
plt.scatter(filtered_data['Longitude'], filtered_data['Latitude'], c=filtered_data['cluster'], cmap='viridis', marker='o')
plt.title('Filtered Food Truck Clusters')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
def get_cluster(latitude, longitude):
    # Standardize the input coordinates using the same scaler
    input_coords_scaled = scaler.transform([[latitude, longitude]])

    # Predict the cluster for the input coordinates
    cluster = kmeans.predict(input_coords_scaled)[0]

    return cluster

# %%
input_latitude = 37.7749
input_longitude = -102.4194

result_cluster = get_cluster(input_latitude, input_longitude)
print(f"The truck belongs to Cluster {result_cluster}")
# Out:
# The truck belongs to Cluster 3
# /home/jack/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
input_latitude = 37.7749
input_longitude = -162.4194

result_cluster = get_cluster(input_latitude, input_longitude)
print(f"The truck belongs to Cluster {result_cluster}")
# Out:
# The truck belongs to Cluster 9
# /home/jack/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
